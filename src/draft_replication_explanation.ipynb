# %% [markdown]
# # Replication Explanation
# This notebook aims to explain the definitions and data and how we manage to replicate the columns in the He table.

# %% [markdown]
# ## Variable Descriptions
# intermediary_capital_ratio
# --------------------------
# The end of period ratio of total market cap to (total market cap + book assets - book equity)
# of NY Fed primary dealers' publicly-traded holding companies.
#
# intermediary_capital_risk_factor
# --------------------------------
# AR(1) innovations to the intermediary_capital_ratio scaled by lagged intermediary_capital_ratio.
# Note: In extending the intermediary_capital_risk_factor, we retain the AR(1)
# coefficients used in the paper.
#
# intermediary_value_weighted_investment_return
# ---------------------------------------------
# The value-weighted investment return to a portfolio of NY Fed primary dealers'
# publicly-traded holding companies. Unlike the intermediary_capital_risk_factor,
# this portfolio is tradable, and performed similarly as a pricing factor.
#
# intermediary_leverage_ratio_squared
# -----------------------------------
# This level variable, defined as (1/intermediary_capital_ratio)^2 was used
# for preliminary predictive tests in the paper, as prescribed by the HK model.

# %% [markdown]
# ## Pull NY Fed Data
# (+variable codebook)

# %%
#do i need to upload the file to github so that it can be downloaded automatically in the future?
import pandas as pd
import numpy as np
dfs_raw = pd.read_excel("../data_manual/Dealer_Lists_1960_to_2014.xls", sheet_name="Dealer Alpha",skiprows=2)

# %%
dealer_df = dfs_raw[dfs_raw["End Date"] == "Current Dealer"].drop(dfs_raw.columns[-1],axis=1)
dealer_df["Primary Dealer"] = dealer_df["Primary Dealer"].str.strip()
dealer_df.count()
# Out:
# Primary Dealer    22
# Start Date        22
# End Date          22
# dtype: int64

# %% [markdown]
# ### Manually add company name

# %%
comp_holding_company = ["(bank of nova scotia)","BARCLAYS PLC", "(bank of montreal)", "BNP PARIBAS", "(cantor firzgerald)", "CITIGROUP INC", "CREDIT SUISSE GROUP", "DAIWA SECURITIES GROUP INC", "DEUTSCHE BANK AG", "GOLDMAN SACHS GROUP INC", "HSBC HLDGS PLC", "JPMORGAN CHASE & CO", "JEFFERIES FINANCIAL GRP INC", "BANK OF AMERICA CORP", "MIZUHO FINANCIAL GROUP INC", "MORGAN STANLEY", "NOMURA HOLDINGS INC", "(rbc)", "ROYAL BANK OF SCOTLAND LTD", "SOCIETE GENERALE GROUP", "(td)", "UBS GROUP AG" ]

# %%
markit_holding_company = ["The Bank of Nova Scotia","Barclays PLC", "Bank of Montreal", "BNP PARIBAS", "Cantor Fitzgerald, L.P.", "Citigroup Inc.", "Credit Suisse Group AG", "Daiwa Securities Group Inc.", "DEUTSCHE BANK AKTIENGESELLSCHAFT", "The Goldman Sachs Group, Inc.", "HSBC HOLDINGS plc", "JPMorgan Chase & Co.", "Jefferies Group LLC", "Bank of America Corporation", "Mizuho Holdings Inc.", "Morgan Stanley", "Nomura Holdings, Inc.", "Royal Bank of Canada", "The Royal Bank Of Scotland Group public limited company", "SOCIETE GENERALE", "The Toronto-Dominion Bank", "UBS AG" ]

# %%
dealer_df["markit"] = markit_holding_company
dealer_df["comp"] = comp_holding_company
dealer_df["comp"] = dealer_df["comp"].replace(r"\(.*\)", np.nan, regex=True)

# %%
dealer_df = dealer_df.drop(columns=["End Date","Start Date"])
dealer_df = dealer_df.reset_index(drop=True)
dealer_df.to_csv("../data_manual/dealer_name_reference.csv")

# %%
dealer_df.head(5)
# Out:
#                          Primary Dealer                   markit          comp
# 0  BANK OF NOVA SCOTIA, NEW YORK AGENCY  The Bank of Nova Scotia           NaN
# 1                 BARCLAYS CAPITAL INC.             Barclays PLC  BARCLAYS PLC
# 2             BMO CAPITAL MARKETS CORP.         Bank of Montreal           NaN
# 3          BNP PARIBAS SECURITIES CORP.              BNP PARIBAS   BNP PARIBAS
# 4               CANTOR FITZGERALD & CO.  Cantor Fitzgerald, L.P.           NaN

# %% [markdown]
# ## Pull WRDS data
#
# https://wrds-www.wharton.upenn.edu/pages/support/manuals-and-overviews/compustat/north-america-global-bank/wrds-overview-compustat-north-america-global-bank/
# GVKEY
# DATADATE
# INDFMT
# DATAFMT
# CONSOL
# POPSRC

# %%
import wrds

# Connect to WRDS
from settings import config
# Make sure that you have included the line
# WRDS_USERNAME = your_wrds_username
# in the .env file
WRDS_USERNAME = config("WRDS_USERNAME") 
db = wrds.Connection(wrds_username=WRDS_USERNAME)

# Check available datasets
db.list_libraries()[:10]
# Out:
# Loading library list...
# Done
# ['aha_sample',
#  'ahasamp',
#  'audit',
#  'audit_acct_os',
#  'audit_audit_comp',
#  'audit_common',
#  'audit_corp_legal',
#  'auditsmp',
#  'auditsmp_all',
#  'bank']

# %%
dfdf = db.get_table(library="markit",table="redent")

# %%
db.describe_table(library="markit",table="redent")
# Out:
# Approximately 17984 rows in markit.redent.
#                 name  nullable           type  \
# 0            redcode      True     VARCHAR(6)
# 1       entity_cusip      True     VARCHAR(6)
# 2             ticker      True    VARCHAR(30)
# 3    referenceentity      True   VARCHAR(500)
# 4          shortname      True   VARCHAR(100)
# 5                lei      True    VARCHAR(20)
# 6        entity_type      True    VARCHAR(20)
# 7       jurisdiction      True   VARCHAR(500)
# 8         depthlevel      True     VARCHAR(4)
# 9       markitsector      True   VARCHAR(500)
# 10       entity_form      True    VARCHAR(20)
# 11   companynum_type      True   VARCHAR(200)
# 12        companynum      True    VARCHAR(50)
# 13  alternativenames      True  VARCHAR(2000)
# 14        recorddate      True           DATE
# 15           validto      True           DATE
# 16         validfrom      True           DATE
#
#                                   comment
# 0      REDCODE (Markit Primary Entity ID)
# 1         Ref Entity CUSIP (6 characters)
# 2                    Markit Entity Ticker
# 3        Reference Entity Full Legal Name
# 4                       Entity Short Name
# 5                 Legal Entity Identifier
# 6                   Reference Entity Type
# 7                  Jurisdiction of Entity
# 8             Depth of Markit CDS Pricing
# 9           Markit Sectors Classification
# 10            Reference Entity Legal Form
# 11                    Company Number Type
# 12   Company Nbr from Entity Jurisdiction
# 13               Entity Alternative Names
# 14  Date Verified for "scrubbed" entities
# 15                  Date REDCODE Valid To
# 16                Date REDCODE Valid From

# %%
merged_df = pd.merge(dfdf, dealer_df, left_on="referenceentity", right_on="markit", how="right")

# %%
merged_df.head(5)
# Out:
#   redcode entity_cusip  ticker          referenceentity             shortname  \
# 0  CC6EHY       C0689P     BNS  The Bank of Nova Scotia        Bk Nova Scotia
# 1  GG8839       G08036    BACR             Barclays PLC          Barclays PLC
# 2  CC676B       C06156     BMO         Bank of Montreal           Bk Montreal
# 3  05ABBF       05565A     BNP              BNP PARIBAS           BNP Paribas
# 4  14BE77       138616  CANFIT  Cantor Fitzgerald, L.P.  Cantor Fitzgerald LP
#
#                     lei entity_type       jurisdiction depthlevel  \
# 0  L3I9ZG2KFGXZ61BMYR72    StatBody             Canada       None
# 1  213800LBQA1Y9L22JB70        Corp  England and Wales       High
# 2  NQQ6HPCNCCU6TUTQYE16    StatBody             Canada       None
# 3  R0MUWSFPU8MPRO8K5P83        Corp             France       High
# 4  549300RLUEEVQEMX0450        Corp      Delaware (US)       None
#
#   markitsector entity_form                    companynum_type   companynum  \
# 0   Financials        CORP                               None         None
# 1   Financials         PLC             English Company Number        48839
# 2   Financials        CORP                               None         None
# 3   Financials          SA  French Company Number (RCS Paris)  662 042 449
# 4   Financials        None                               None         None
#
#                alternativenames  recorddate validto   validfrom  \
# 0  La Banque de Nouvelle-Ecosse  2023-11-21    None        None
# 1                          None  2025-02-10    None        None
# 2            Banque de Montreal  2022-05-19    None        None
# 3                          None  2024-10-01    None  1998-05-12
# 4                          None        None    None        None
#
#                          Primary Dealer                   markit          comp
# 0  BANK OF NOVA SCOTIA, NEW YORK AGENCY  The Bank of Nova Scotia           NaN
# 1                 BARCLAYS CAPITAL INC.             Barclays PLC  BARCLAYS PLC
# 2             BMO CAPITAL MARKETS CORP.         Bank of Montreal           NaN
# 3          BNP PARIBAS SECURITIES CORP.              BNP PARIBAS   BNP PARIBAS
# 4               CANTOR FITZGERALD & CO.  Cantor Fitzgerald, L.P.           NaN

# %%
## we need an extra step to delete the unnecessary BOA row, but unsure about what to delete yet.

# %% [markdown]
# ## Merge with CRSP-Compustat
# we followed this instruction: https://wrds-www.wharton.upenn.edu/pages/wrds-research/database-linking-matrix/linking-markit-with-crsp/

# %%
map_df = db.raw_sql(
'''
SELECT distinct
 b.permno, b.hdrCusip, b.ticker as crspTicker, b.permco, b.issuernm
FROM crsp.stksecurityinfohdr as b
''')

# %%
db.describe_table(library="crsp",table="stksecurityinfohdr")
# Out:
# Approximately 37796 rows in crsp.stksecurityinfohdr.
#                  name  nullable         type                           comment
# 0              permno      True      INTEGER                            PERMNO
# 1      secinfostartdt      True         DATE   Security Information Start Date
# 2        secinfoenddt      True         DATE     Security Information End Date
# 3       securitybegdt      True         DATE          Begin Date of Stock Data
# 4       securityenddt      True         DATE            End Date of Stock Data
# 5      securityhdrflg      True   VARCHAR(1)              Security Header Flag
# 6            hdrcusip      True   VARCHAR(8)        Header CUSIP -8 Characters
# 7           hdrcusip9      True   VARCHAR(9)        Header CUSIP -9 Characters
# 8               cusip      True   VARCHAR(8)                             CUSIP
# 9              cusip9      True   VARCHAR(9)                            CUSIP9
# 10        primaryexch      True   VARCHAR(1)                  Primary Exchange
# 11    conditionaltype      True   VARCHAR(3)                  Conditional Type
# 12       exchangetier      True   VARCHAR(3)                     Exchange Tier
# 13   tradingstatusflg      True   VARCHAR(1)               Trading Status Flag
# 14         securitynm      True  VARCHAR(60)                     Security Name
# 15         shareclass      True   VARCHAR(1)                       Share Class
# 16           usincflg      True   VARCHAR(1)             US Incorporation Flag
# 17         issuertype      True   VARCHAR(4)                       Issuer Type
# 18       securitytype      True   VARCHAR(4)                     Security Type
# 19    securitysubtype      True   VARCHAR(3)                 Security Sub-Type
# 20          sharetype      True   VARCHAR(3)                        Share Type
# 21  securityactiveflg      True   VARCHAR(1)              Security Active Flag
# 22      delactiontype      True   VARCHAR(5)   Delisting Corporate Action Type
# 23      delstatustype      True   VARCHAR(4)  Delisting Completion Status Type
# 24      delreasontype      True   VARCHAR(5)             Delisting Reason Type
# 25     delpaymenttype      True   VARCHAR(4)    Delisting Payment Summary Type
# 26             ticker      True   VARCHAR(5)                            Ticker
# 27      tradingsymbol      True   VARCHAR(7)                    Trading Symbol
# 28             permco      True      INTEGER                            PERMCO
# 29              siccd      True      INTEGER                          Sic Code
# 30              naics      True   VARCHAR(6)                        NAICS Code
# 31        icbindustry      True   VARCHAR(7)                 ICB Industry Code
# 32        uesindustry      True  VARCHAR(10)                 UES Industry Code
# 33         nasdcompno      True      INTEGER             Nasdaq Company Number
# 34         nasdissuno      True      INTEGER               Nasdaq Issue Number
# 35           issuernm      True  VARCHAR(50)                       Issuer Name

# %%
db.describe_table(library="crsp",table="msf")
# Out:
# Approximately 5150989 rows in crsp.msf.
#         name  nullable              type  \
# 0      cusip      True        VARCHAR(8)
# 1     permno      True           INTEGER
# 2     permco      True           INTEGER
# 3     issuno      True           INTEGER
# 4      hexcd      True          SMALLINT
# 5     hsiccd      True           INTEGER
# 6       date      True              DATE
# 7      bidlo      True    NUMERIC(11, 5)
# 8      askhi      True    NUMERIC(11, 5)
# 9        prc      True    NUMERIC(11, 5)
# 10       vol      True    NUMERIC(10, 0)
# 11       ret      True    NUMERIC(10, 6)
# 12       bid      True    NUMERIC(11, 5)
# 13       ask      True    NUMERIC(11, 5)
# 14    shrout      True  DOUBLE PRECISION
# 15    cfacpr      True  DOUBLE PRECISION
# 16   cfacshr      True  DOUBLE PRECISION
# 17    altprc      True    NUMERIC(11, 5)
# 18    spread      True    NUMERIC(10, 5)
# 19  altprcdt      True              DATE
# 20      retx      True    NUMERIC(10, 6)
#
#                                            comment
# 0                                     CUSIP Header
# 1                                           PERMNO
# 2                                           PERMCO
# 3                              Nasdaq Issue Number
# 4                             Exchange Code Header
# 5   Standard Industrial Classification Code Header
# 6                              Date of Observation
# 7                                 Bid or Low Price
# 8                                Ask or High Price
# 9                         Price or Bid/Ask Average
# 10                                          Volume
# 11                                         Returns
# 12                                             Bid
# 13                                             Ask
# 14                              Shares Outstanding
# 15              Cumulative Factor to Adjust Prices
# 16          Cumulative Factor to Adjust Shares/Vol
# 17                                 Price Alternate
# 18                      Spread Between Bid and Ask
# 19                            Alternate Price Date
# 20                       Returns without Dividends

# %%
### Get red entity information
redent = db.get_table(library='markit', table='redent')

# Quick check to confirm that it is the header information
# i.e. each redcode is mapped to only one entity 
# and doesn't contain historical records
redcnt = redent.groupby(['redcode'])['entity_cusip'].count().reset_index().rename(columns={'entity_cusip':'cusipCnt'})
redcnt.cusipCnt.max()
### Each redcode has only one entity_cusip mapped
### so it is indeed only header record

### Get information from CRSP header table
crspHdr = db.raw_sql('select permno, permco, hdrcusip, ticker, issuernm from crsp.stksecurityinfohdr')
crspHdr['cusip6'] = crspHdr.hdrcusip.str[:6]
crspHdr = crspHdr.rename(columns={'ticker': 'crspTicker'})

### First Route - Link with 6-digit cusip
_cdscrsp1 = pd.merge(redent, crspHdr, how='left', left_on='entity_cusip', right_on='cusip6')

# store linked results through CUSIP
_cdscrsp_cusip = _cdscrsp1.loc[_cdscrsp1.permno.notna()].copy()
_cdscrsp_cusip['flg'] = 'cusip'

# continue to work with non-linked records
_cdscrsp2 = _cdscrsp1.loc[_cdscrsp1.permno.isna()].copy().drop(columns=['permno','permco','hdrcusip','crspTicker','issuernm','cusip6'])

### Second Route - Link with Ticker
_cdscrsp3 = pd.merge(_cdscrsp2, crspHdr, how = 'left', left_on = 'ticker', right_on='crspTicker')
_cdscrsp_ticker = _cdscrsp3.loc[_cdscrsp3.permno.notna()].copy()
_cdscrsp_ticker['flg']='ticker'

# %%
import wrds
import os
import numpy as np
import pandas as pd

# display all columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import pickle as pkl
from fuzzywuzzy import fuzz

cdscrsp = pd.concat([_cdscrsp_cusip, _cdscrsp_ticker], ignore_index=True, axis=0)

# Check similarity ratio of company names
crspNameLst= cdscrsp.issuernm.str.upper().tolist()
redNameLst = cdscrsp.shortname.str.upper().tolist()
len(crspNameLst), len(redNameLst)

nameRatio  = [] # blank list to store fuzzy ratio

for i in range(len(redNameLst)):
    ratio = fuzz.partial_ratio(redNameLst[i], crspNameLst[i])
    nameRatio.append(ratio)
    
cdscrsp['nameRatio']=nameRatio
# Out:
# c:\miniforge3\envs\blank\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
final_df = cdscrsp.merge(merged_df["referenceentity"], on = "referenceentity", how="right")
final_df = final_df[final_df["redcode"].isna() == False]
final_df.drop_duplicates()
# Out:
#    redcode entity_cusip  ticker                   referenceentity  \
# 0   CC6EHY       C0689P     BNS           The Bank of Nova Scotia
# 1   CC6EHY       C0689P     BNS           The Bank of Nova Scotia
# 3   CC676B       C06156     BMO                  Bank of Montreal
# 4   05ABBF       05565A     BNP                       BNP PARIBAS
# 5   05ABBF       05565A     BNP                       BNP PARIBAS
# 7   189BFD       172967       C                    Citigroup Inc.
# 10  2H6677       251525      DB  DEUTSCHE BANK AKTIENGESELLSCHAFT
# 11  3B955H       38141G      GS     The Goldman Sachs Group, Inc.
# 12  4E46A8       404280    HSBC                 HSBC HOLDINGS plc
# 13  4C933G       48121F     JPM              JPMorgan Chase & Co.
# 14  4C933G       48121F     JPM              JPMorgan Chase & Co.
# 16  0G6555       060505     BAC       Bank of America Corporation
# 20  678B8A       617446     MWD                    Morgan Stanley
# 21  6BA88M       65535H  NOMURA             Nomura Holdings, Inc.
# 22  CJGGB6       C79742      RY              Royal Bank of Canada
# 25  8HA277       891161      TD         The Toronto-Dominion Bank
# 26  HPHB2J       H8920J     UBS                            UBS AG
# 27  HPHB2J       H8920J     UBS                            UBS AG
#
#                shortname                   lei entity_type       jurisdiction  \
# 0         Bk Nova Scotia  L3I9ZG2KFGXZ61BMYR72    StatBody             Canada
# 1         Bk Nova Scotia  L3I9ZG2KFGXZ61BMYR72    StatBody             Canada
# 3            Bk Montreal  NQQ6HPCNCCU6TUTQYE16    StatBody             Canada
# 4            BNP Paribas  R0MUWSFPU8MPRO8K5P83        Corp             France
# 5            BNP Paribas  R0MUWSFPU8MPRO8K5P83        Corp             France
# 7          Citigroup Inc  6SHGI4ZSSLCXXQSBB395        Corp      Delaware (US)
# 10        Deutsche Bk AG  7LTWFZYICNSX8D621K86        Corp            Germany
# 11  Goldman Sachs Gp Inc  784F5XWPLTWKTBV3E584        Corp      Delaware (US)
# 12        HSBC Hldgs plc  MLU0ZO3ML4LN2LL2TL39        Corp  England and Wales
# 13   JPMorgan Chase & Co  8I5DZWZKVSZI1NUHU748        Corp      Delaware (US)
# 14   JPMorgan Chase & Co  8I5DZWZKVSZI1NUHU748        Corp      Delaware (US)
# 16          Bk Amer Corp                  None        Corp      Delaware (US)
# 20        Morgan Stanley  IGJSJL3JD5P30I6NJZ34        Corp      Delaware (US)
# 21      Nomura Hldgs Inc  549300B3CEAHYG7K8164        Corp              Japan
# 22          Royal Bk Cda  ES7IP3U3RHIGC71XBU11    StatBody             Canada
# 25   Toronto Dominion Bk  PT3QB789TSUIDF371261    StatBody             Canada
# 26                UBS AG  BFM8T61CT2L1QCEMIK50        Corp        Switzerland
# 27                UBS AG  BFM8T61CT2L1QCEMIK50        Corp        Switzerland
#
#    depthlevel markitsector entity_form  \
# 0        None   Financials        CORP
# 1        None   Financials        CORP
# 3        None   Financials        CORP
# 4        High   Financials          SA
# 5        High   Financials          SA
# 7        High   Financials        CORP
# 10        Med   Financials          AG
# 11       High   Financials        CORP
# 12        Med   Financials         PLC
# 13       High   Financials        CORP
# 14       High   Financials        CORP
# 16       None   Financials        CORP
# 20        Med   Financials        CORP
# 21        Med   Financials        CORP
# 22        Low   Financials        None
# 25       None   Financials        CORP
# 26        Med   Financials          AG
# 27        Med   Financials          AG
#
#                                       companynum_type       companynum  \
# 0                                                None             None
# 1                                                None             None
# 3                                                None             None
# 4                   French Company Number (RCS Paris)      662 042 449
# 5                   French Company Number (RCS Paris)      662 042 449
# 7                                                None             None
# 10  Commercial Register Number, Frankfurt am Main,...        HRB 30000
# 11                                               None             None
# 12                             English Company Number           617987
# 13                                               None             None
# 14                                               None             None
# 16                                               None             None
# 20                                               None             None
# 21                            Japanese Company Number   0100-01-034881
# 22                                               None             None
# 25                                               None             None
# 26                               Swiss Company Number  CHE-101.329.561
# 27                               Swiss Company Number  CHE-101.329.561
#
#                    alternativenames  recorddate     validto   validfrom  \
# 0      La Banque de Nouvelle-Ecosse  2023-11-21        None        None
# 1      La Banque de Nouvelle-Ecosse  2023-11-21        None        None
# 3                Banque de Montreal  2022-05-19        None        None
# 4                              None  2024-10-01        None  1998-05-12
# 5                              None  2024-10-01        None  1998-05-12
# 7                              None  2025-01-15        None  2005-08-01
# 10                             None  2024-09-20        None  2002-08-08
# 11                             None  2024-08-21        None        None
# 12                             None  2025-01-16        None        None
# 13                             None  2025-01-16        None  2004-07-20
# 14                             None  2025-01-16        None  2004-07-20
# 16                             None  2003-11-12  2004-04-01        None
# 20                             None  2025-01-15        None  2002-06-20
# 21  Nomura Holdings Kabushikikaisha  2025-01-16        None        None
# 22                             None  2024-09-18        None        None
# 25       La Banque Toronto-Dominion  2017-11-27        None        None
# 26                  UBS Inc.;UBS SA  2021-10-21        None        None
# 27                  UBS Inc.;UBS SA  2021-10-21        None        None
#
#      permno   permco  hdrcusip crspTicker                          issuernm  \
# 0   42606.0  20339.0  05596130        BNS                          B N S CO
# 1   89428.0  43264.0  06414910        BNS               BANK OF NOVA SCOTIA
# 3   81284.0  29146.0  06367110        BMO                 BANK MONTREAL QUE
# 4   53487.0  25319.0  07011310        BNP              BASIN PETROLEUM CORP
# 5   75037.0  20314.0  05564T10        BNP  B N P RESIDENTIAL PROPERTIES INC
# 7   70519.0  20483.0  17296742          C                     CITIGROUP INC
# 10  89199.0  42291.0  D1819089         DB                 DEUTSCHE BANK A G
# 11  86868.0  35048.0  38141G10         GS           GOLDMAN SACHS GROUP INC
# 12  87033.0  35175.0  40428040       HSBC              H S B C HOLDINGS PLC
# 13  47896.0  20436.0  46625H10        JPM               JPMORGAN CHASE & CO
# 14  48071.0  21222.0  61688010        JPM               MORGAN J P & CO INC
# 16  59408.0   3151.0  06050510        BAC              BANK OF AMERICA CORP
# 20  69032.0  21224.0  61744644         MS   MORGAN STANLEY DEAN WITTER & CO
# 21  89256.0  42522.0  65535H20        NMR               NOMURA HOLDINGS INC
# 22  82654.0  29151.0  78008710         RY    ROYAL BANK CANADA MONTREAL QUE
# 25  83835.0  29152.0  89116050         TD         TORONTO DOMINION BANK ONT
# 26  15054.0  55100.0  H4209710        UBS                   U B S GROUP A G
# 27  75849.0  22126.0  91164620        UBS                U S BIOSCIENCE INC
#
#     cusip6     flg  nameRatio
# 0   055961  ticker       62.0
# 1   064149  ticker       86.0
# 3   063671  ticker       91.0
# 4   070113  ticker       27.0
# 5   05564T  ticker       55.0
# 7   172967   cusip      100.0
# 10  D18190  ticker       86.0
# 11  38141G   cusip       85.0
# 12  404280   cusip       79.0
# 13  46625H  ticker      100.0
# 14  616880  ticker       63.0
# 16  060505   cusip       75.0
# 20  617446   cusip      100.0
# 21  65535H   cusip       81.0
# 22  780087  ticker       83.0
# 25  891160  ticker       95.0
# 26  H42097  ticker       67.0
# 27  911646  ticker       50.0

# %%
## manually select rows.
# Ensure all values in permno_lst are converted to integers
permno_lst = final_df["permno"].dropna().astype(int).tolist()

# Format as a properly structured SQL IN clause
permno_str = "(" + ",".join(map(str, permno_lst)) + ")"

# Print the formatted string (for debugging)
print(permno_str)  # Output should look like: (42606,89428,81284,53487,75037,...)
# Out:
# (42606,89428,81284,53487,75037,70519,89199,86868,87033,47896,48071,59408,59408,59408,69032,89256,82654,83835,15054,75849)

# %%
query = f"""
SELECT 
    date,
    msf.permno, msf.permco, shrcd, exchcd, comnam, shrcls, 
    ret, retx, dlret, dlretx, dlstcd,
    prc, altprc, vol, shrout, cfacshr, cfacpr,
    naics, siccd
FROM crsp.msf AS msf

LEFT JOIN 
    crsp.msenames as msenames
ON 
    msf.permno = msenames.permno AND
    msenames.namedt <= msf.date AND
    msf.date <= msenames.nameendt
LEFT JOIN 
    crsp.msedelist as msedelist
ON 
    msf.permno = msedelist.permno AND
    date_trunc('month', msf.date)::date =
    date_trunc('month', msedelist.dlstdt)::date
WHERE msf.permno IN {permno_str}
"""

db = wrds.Connection(wrds_username=WRDS_USERNAME)
df1 = db.raw_sql(query, date_cols=["date", "namedt", "nameendt", "dlstdt"])
# Out:
# Loading library list...
# Done

# %%
df1.head(5)
# Out:
#         date  permno  permco  shrcd  exchcd           comnam shrcls       ret  \
# 0 2018-08-31   15054   55100   12.0     1.0  U B S GROUP A G   None -0.046285
# 1 2018-09-28   15054   55100   12.0     1.0  U B S GROUP A G   None  0.004470
# 2 2018-10-31   15054   55100   12.0     1.0  U B S GROUP A G   None -0.116338
# 3 2018-11-30   15054   55100   12.0     1.0  U B S GROUP A G   None -0.026619
# 4 2018-12-31   15054   55100   12.0     1.0  U B S GROUP A G   None -0.084996
#
#        retx  dlret  dlretx  dlstcd    prc  altprc       vol     shrout  \
# 0 -0.046285    NaN     NaN     NaN  15.66   15.66  395926.0  3729120.0
# 1  0.004470    NaN     NaN     NaN  15.73   15.73  281879.0  3729120.0
# 2 -0.116338    NaN     NaN     NaN  13.90   13.90  532175.0  3726373.0
# 3 -0.026619    NaN     NaN     NaN  13.53   13.53  441854.0  3726373.0
# 4 -0.084996    NaN     NaN     NaN  12.38   12.38  763803.0  3726373.0
#
#    cfacshr  cfacpr   naics   siccd
# 0      1.0     1.0  525990  6021.0
# 1      1.0     1.0  525990  6021.0
# 2      1.0     1.0  525990  6021.0
# 3      1.0     1.0  525990  6021.0
# 4      1.0     1.0  525990  6021.0

# %%
len(df1.permno.value_counts())
# Out:
# 18

# %%
df_counts = df1.groupby(["permno", "comnam"]).size()
print(df_counts)
# Out:
# permno  comnam
# 15054   U B S GROUP A G                     122
# 42606   B N S CO                             10
#         BROWN & SHARPE MFG CO               425
# 47896   CHASE MANHATTAN CORP NEW             57
#         CHEMICAL BANKING CORP                96
#         CHEMICAL NEW YORK CORP              229
#         J P MORGAN CHASE & CO                42
#         JPMORGAN CHASE & CO                 246
# 48071   MORGAN J P & CO INC                 381
# 53487   BASIN PETROLEUM CORP                 50
# 59408   BANK OF AMERICA CORP                309
#         BANKAMERICA CORP NEW                  6
#         N C N B CORP                        229
#         NATIONSBANK CORP                     81
# 69032   MORGAN STANLEY DEAN WITTER & CO     322
#         MORGAN STANLEY DEAN WITTER D & C      9
#         MORGAN STANLEY GROUP INC            135
# 70519   CITIGROUP INC                       315
#         COMMERCIAL CREDIT CO                 19
#         COMMERCIAL CREDIT GROUP INC           7
#         PRIMERICA CORP NEW                   61
#         TRAVELERS GROUP INC                  42
#         TRAVELERS INC                        15
# 75037   B N P RESIDENTIAL PROPERTIES INC     83
#         BODDIE NOELL PROPERTIES INC          66
#         BODDIE NOELL RESTAURNT PPTYS IN      89
# 75849   U S BIOSCIENCE INC                  120
# 81284   BANK MONTREAL QUE                   363
# 82654   ROYAL BANK CANADA MONTREAL QUE      351
# 83835   TORONTO DOMINION BANK ONT           341
# 86868   GOLDMAN SACHS GROUP INC             308
# 87033   H S B C HOLDINGS PLC                306
# 89199   DEUTSCHE BANK A G                   279
# 89256   NOMURA HOLDINGS INC                 277
# 89428   BANK OF NOVA SCOTIA                 271
# dtype: int64

# %% [markdown]
# ## Calculation

# %%
df1["adj_shrout"] = df1["shrout"] * df1["cfacshr"]
df1["adj_prc"] = df1["prc"].abs() / df1["cfacpr"]
df1["market_cap"] = df1["adj_prc"] * df1["adj_shrout"]

# %%
fundq_des = db.describe_table(library="comp",table="fundq")
fundq_des[fundq_des["name"]=="conm"]
# Out:
# Approximately 2048197 rows in comp.fundq.
#     name  nullable         type       comment
# 11  conm      True  VARCHAR(70)  Company Name

# %%
db = wrds.Connection(wrds_username=WRDS_USERNAME)

fundq_com_df = db.raw_sql(
    """
    SELECT DISTINCT conm
    FROM comp.fundq;
    """
)
# Out:
# Loading library list...
# Done

# %%
fundq_com_df[fundq_com_df.conm.str.contains("ABN")]
# Out:
#                                conm
# 7251           ABN-AMRO HOLDINGS NV
# 25659  YIELDMAX ABNB OPT INCM STRAT
