# %% [markdown]
# # Replication Explanation
# This notebook aims to explain the definitions and data and how we manage to replicate the columns in the He table.

# %% [markdown]
# ## Variable Descriptions
# intermediary_capital_ratio
# --------------------------
# The end of period ratio of total market cap to (total market cap + book assets - book equity)
# of NY Fed primary dealers' publicly-traded holding companies.
#
# intermediary_capital_risk_factor
# --------------------------------
# AR(1) innovations to the intermediary_capital_ratio scaled by lagged intermediary_capital_ratio.
# Note: In extending the intermediary_capital_risk_factor, we retain the AR(1)
# coefficients used in the paper.
#
# intermediary_value_weighted_investment_return
# ---------------------------------------------
# The value-weighted investment return to a portfolio of NY Fed primary dealers'
# publicly-traded holding companies. Unlike the intermediary_capital_risk_factor,
# this portfolio is tradable, and performed similarly as a pricing factor.
#
# intermediary_leverage_ratio_squared
# -----------------------------------
# This level variable, defined as (1/intermediary_capital_ratio)^2 was used
# for preliminary predictive tests in the paper, as prescribed by the HK model.

# %% [markdown]
# ## Pull NY Fed Data
# (+variable codebook)

# %%
#do i need to upload the file to github so that it can be downloaded automatically in the future?
import pandas as pd
dfs_raw = pd.read_excel("../data_manual/Dealer_Lists_1960_to_2014.xls", sheet_name="Dealer Alpha",skiprows=2)

# %%
dealer_df = dfs_raw[dfs_raw["End Date"] == "Current Dealer"].drop(dfs_raw.columns[-1],axis=1)
dealer_df["Primary Dealer"] = dealer_df["Primary Dealer"].str.strip()
dealer_df.count()
# Out:
# Primary Dealer    22
# Start Date        22
# End Date          22
# dtype: int64

# %%
dealer_df
# Out:
#                                         Primary Dealer Start Date  \
# 9                 BANK OF NOVA SCOTIA, NEW YORK AGENCY 2011-10-04
# 11                               BARCLAYS CAPITAL INC. 1998-04-01
# 19                           BMO CAPITAL MARKETS CORP. 2011-10-04
# 21                        BNP PARIBAS SECURITIES CORP. 2000-09-15
# 28                             CANTOR FITZGERALD & CO. 2006-08-01
# 43                       CITIGROUP GLOBAL MARKETS INC. 2003-04-07
# 50                  CREDIT SUISSE SECURITIES (USA) LLC 2006-01-16
# 54                  DAIWA CAPITAL MARKETS AMERICA INC. 2010-04-01
# 61                       DEUTSCHE BANK SECURITIES INC. 2002-03-30
# 79                                GOLDMAN, SACHS & CO. 1974-12-04
# 85                          HSBC SECURITIES (USA) INC. 1999-06-01
# 91                          J.P. MORGAN SECURITIES LLC 2010-09-01
# 93                                       JEFFERIES LLC 2013-03-01
# 107  MERRILL LYNCH, PIERCE, FENNER & SMITH INCORPOR... 2010-11-01
# 110                         MIZUHO SECURITIES USA INC. 2002-04-01
# 112                           MORGAN STANLEY & CO. LLC 2011-05-31
# 120                NOMURA SECURITIES INTERNATIONAL,INC 2009-07-27
# 129                           RBC CAPITAL MARKETS, LLC 2010-11-01
# 130                                RBS SECURITIES INC. 2009-04-01
# 132                        SG AMERICAS SECURITIES, LLC 2011-02-02
# 151                            TD SECURITIES (USA) LLC 2014-02-11
# 157                                UBS SECURITIES LLC. 2003-06-09
#
#            End Date
# 9    Current Dealer
# 11   Current Dealer
# 19   Current Dealer
# 21   Current Dealer
# 28   Current Dealer
# 43   Current Dealer
# 50   Current Dealer
# 54   Current Dealer
# 61   Current Dealer
# 79   Current Dealer
# 85   Current Dealer
# 91   Current Dealer
# 93   Current Dealer
# 107  Current Dealer
# 110  Current Dealer
# 112  Current Dealer
# 120  Current Dealer
# 129  Current Dealer
# 130  Current Dealer
# 132  Current Dealer
# 151  Current Dealer
# 157  Current Dealer

# %% [markdown]
# ### Manually add company name

# %%
comp_holding_company = ["(bank of nova scotia)","BARCLAYS PLC", "(bank of montreal)", "BNP PARIBAS", "(cantor firzgerald)", "CITIGROUP INC", "CREDIT SUISSE GROUP", "DAIWA SECURITIES GROUP INC", "DEUTSCHE BANK AG", "GOLDMAN SACHS GROUP INC", "HSBC HLDGS PLC", "JPMORGAN CHASE & CO", "JEFFERIES FINANCIAL GRP INC", "BANK OF AMERICA CORP", "MIZUHO FINANCIAL GROUP INC", "MORGAN STANLEY", "NOMURA HOLDINGS INC", "(rbc)", "ROYAL BANK OF SCOTLAND LTD", "SOCIETE GENERALE GROUP", "(td)", "UBS GROUP AG" ]

# %%
# Deutsche Bank AG, Societe Generale, failed to find in redlookup
# Mizuho does not match table 1
# RBC not match
markit_holding_company = ["The Bank of Nova Scotia","Barclays PLC", "Bank of Montreal", "BNP PARIBAS", "Cantor Fitzgerald, L.P.", "Citigroup Inc.", "Credit Suisse Group AG", "Daiwa Securities Group Inc.", "Deutsche Bk AG", "The Goldman Sachs Group, Inc.", "HSBC HOLDINGS plc", "JPMorgan Chase & Co.", "Jefferies Group LLC", "Bank of America Corporation", "Mizuho Financial Group, Inc.", "Morgan Stanley", "Nomura Holdings, Inc.", "Royal Bank of Canada", "The Royal Bank of Scotland N.V.", "Societe Generale", "The Toronto-Dominion Bank", "UBS AG" ]

# %%
dealer_df["markit"] = markit_holding_company
dealer_df["comp"] = comp_holding_company

# %%
dealer_df = dealer_df.drop(columns=["End Date"])

# %%
dfdf[dfdf.referenceentity.str.contains("UBS")]
#dfdf[dfdf.ticker.str.contains("DB")]
# Out:
#       redcode alt_redcode  distance   cusip       ticker  \
# 1878   137EBM        None       0.0  12592K       COMUBS
# 11508  8HHC9L      9BBB8Z      -1.0  89845G  TRUVO-SubCo
# 11509  8HHC9L        None       0.0  89845G  TRUVO-SubCo
# 11510  8HHC9L      9BBB8Z       1.0  89845G  TRUVO-SubCo
# 12739  9J287V        None       0.0  90261U      UBS-Ams
# 12799  9J37BM        None       0.0  90347F       UBSPRE
# 12800  9J37CR        None       0.0  90348J       UBBANK
# 12807  9J387L        None       0.0  90352J         UBSG
# 12808  9J3880        None       0.0  90353X       UBSAME
# 12810  9J389V      9J37DO      -1.0  90354R        UBSGL
# 12811  9J389V      9J37DO       1.0  90354R        UBSGL
# 13723  DLC9C3      GPA78R      -1.0  D8457W       UBSEUR
# 13724  DLC9C3      GPA78R       1.0  D8457W       UBSEUR
# 17160  GM622G      GG58CQ      -1.0  G6020G         MSCL
# 17161  GM622G        None       0.0  G6020G         MSCL
# 17162  GM622G      GG58CQ       1.0  G6020G         MSCL
# 18160  GO99CJ        None       0.0  G8184F   BSY-SKYSSL
# 18754  GPCBEL      GPA7D3      -1.0  G9386F       UBSREO
# 18755  GPCBEL        None       0.0  G9386F       UBSREO
# 18756  GPCBEL      GPA7D3       1.0  G9386F       UBSREO
# 19073  HL629G      2E7941      -2.0  H42097       UBSGRO
# 19074  HL629G      HK9FHL      -1.0  H42097       UBSGRO
# 19075  HL629G      HK9FHL       1.0  H42097       UBSGRO
# 19076  HL629G      2E7941       2.0  H42097       UBSGRO
# 19150  HPHB2J        None       0.0  H8920J          UBS
# 22980  QZBA8G      QZB9F9      -1.0  Q9280G       UBSAUS
# 22981  QZBA8G        None       0.0  Q9280G       UBSAUS
# 22982  QZBA8G      QZB9F9       1.0  Q9280G       UBSAUS
#
#                           referenceentity
# 1878        COMM 2014-UBS5 Mortgage Trust
# 11508              TRUVO SUBSIDIARY CORP.
# 11509              TRUVO SUBSIDIARY CORP.
# 11510              TRUVO SUBSIDIARY CORP.
# 12739                   UBS Americas Inc.
# 12799       UBS PREFERRED FUNDING TRUST V
# 12800                        UBS BANK USA
# 12807  UBS Group Funding (Switzerland) AG
# 12808            UBS AMERICAS HOLDING LLC
# 12810          UBS GLOBAL INVESTMENTS LLC
# 12811          UBS GLOBAL INVESTMENTS LLC
# 13723                       UBS Europe SE
# 13724                       UBS Europe SE
# 17160    MERLIN SUBSIDENCE CLAIMS LIMITED
# 17161    MERLIN SUBSIDENCE CLAIMS LIMITED
# 17162    MERLIN SUBSIDENCE CLAIMS LIMITED
# 18160    SKY SUBSCRIBERS SERVICES LIMITED
# 18754      UBS REORGANISATION 2016-04 LTD
# 18755      UBS REORGANISATION 2016-04 LTD
# 18756      UBS REORGANISATION 2016-04 LTD
# 19073                        UBS Group AG
# 19074                        UBS Group AG
# 19075                        UBS Group AG
# 19076                        UBS Group AG
# 19150                              UBS AG
# 22980               UBS AUSTRALIA PTY LTD
# 22981               UBS AUSTRALIA PTY LTD
# 22982               UBS AUSTRALIA PTY LTD

# %% [markdown]
# ## Pull WRDS data
#
# https://wrds-www.wharton.upenn.edu/pages/support/manuals-and-overviews/compustat/north-america-global-bank/wrds-overview-compustat-north-america-global-bank/
# GVKEY
# DATADATE
# INDFMT
# DATAFMT
# CONSOL
# POPSRC

# %%
import wrds

# Connect to WRDS
from settings import config
# Make sure that you have included the line
# WRDS_USERNAME = your_wrds_username
# in the .env file
WRDS_USERNAME = config("WRDS_USERNAME") 
db = wrds.Connection(wrds_username=WRDS_USERNAME)

# Check available datasets
db.list_libraries()[:10]
# Out:
# Loading library list...
# Done
# ['aha_sample',
#  'ahasamp',
#  'audit',
#  'audit_acct_os',
#  'audit_audit_comp',
#  'audit_common',
#  'audit_corp_legal',
#  'auditsmp',
#  'auditsmp_all',
#  'bank']

# %%
# from IPython.display import display, HTML
# db.connection.rollback()
# db.describe_table(library="comp", table="funda")
# Out:
# Approximately 909402 rows in comp.funda.

# %%
dealer_names = tuple(dealer_df["Primary Dealer"])
if len(dealer_names) == 1:
    dealer_names = f"('{dealer_names[0]}')"  # Ensure proper SQL syntax for a single value
else:
    dealer_names = str(dealer_names)  # Convert tuple to SQL-compatible format
    
query = f"""
    SELECT gvkey, datadate, indfmt, datafmt, consol, popsrc, conm
    FROM comp.funda
    WHERE datadate = '2014-12-31'
"""
#     WHERE UPPER(a.conm) IN {dealer_names}
df = db.raw_sql(query)

# %%
# db.list_tables(library='markit')
# https://wrds-www.wharton.upenn.edu/pages/wrds-research/database-linking-matrix/
db.describe_table(library="markit",table="cds2014")
# Out:
# Approximately 58357712 rows in markit.cds2014.
#           name  nullable              type                           comment
# 0         date      True              DATE            Data Contribution Date
# 1        batch      True        VARCHAR(3)                              None
# 2       ticker      True       VARCHAR(25)                            Ticker
# 3    shortname      True      VARCHAR(100)  Abbreviation of Reference Entity
# 4      redcode      True        VARCHAR(6)                          RED Code
# ..         ...       ...               ...                               ...
# 158     irdv01      True  DOUBLE PRECISION                              None
# 159      rec01      True  DOUBLE PRECISION                              None
# 160         dp      True  DOUBLE PRECISION                              None
# 161        jtd      True  DOUBLE PRECISION                              None
# 162        dtz      True  DOUBLE PRECISION                              None
#
# [163 rows x 4 columns]

# %%
db.get_table(library="markit", table="entity")

# %%
db.list_tables(library="markit",)
# Out:
# ['cds2001',
#  'cds2002',
#  'cds2003',
#  'cds2004',
#  'cds2005',
#  'cds2006',
#  'cds2007',
#  'cds2008',
#  'cds2009',
#  'cds2010',
#  'cds2011',
#  'cds2012',
#  'cds2013',
#  'cds2014',
#  'cds2015',
#  'cds2016',
#  'cds2017',
#  'cds2018',
#  'cds2019',
#  'cds2020',
#  'cds2021',
#  'cds2022',
#  'cds2023',
#  'cds2024',
#  'cds2025',
#  'cdslookup',
#  'cdxcomps',
#  'cdxcomps_chars',
#  'cdxconst',
#  'cdxconst_chars',
#  'chars',
#  'isdatt',
#  'itraxxascomps',
#  'itraxxascomps_chars',
#  'itraxxasconst',
#  'itraxxasconst_chars',
#  'itraxxeucomps',
#  'itraxxeucomps_chars',
#  'itraxxeuconst',
#  'itraxxeuconst_chars',
#  'itraxxsocomps',
#  'itraxxsocomps_chars',
#  'itraxxsoconst',
#  'itraxxsoconst_chars',
#  'red_chars',
#  'redent',
#  'redentaucccy',
#  'redentcorpact',
#  'redentcredauc',
#  'redentisda',
#  'redentrating',
#  'redentsuccession',
#  'redindex',
#  'redlookup',
#  'redobl',
#  'redoblindxconst',
#  'redobllookup',
#  'redoblprospectus',
#  'redoblrefentity']

# %%
db.describe_table(library="markit",table="red")
# Out:
# Approximately 1 rows in markit.red_chars.
#               name  nullable           type  \
# 0          redcode      True     VARCHAR(6)
# 1             tier      True     VARCHAR(8)
# 2              ccy      True     VARCHAR(3)
# 3           ticker      True   VARCHAR(100)
# 4        shortname      True   VARCHAR(100)
# ..             ...       ...            ...
# 82   pairiscurrent      True     VARCHAR(1)
# 83     ispreferred      True     VARCHAR(1)
# 84  publiccomments      True  VARCHAR(4000)
# 85     isdatt_tier      True    VARCHAR(10)
# 86     isdatt_name      True   VARCHAR(200)
#
#                                  comment
# 0                               RED Code
# 1              Instrument Seniority Tier
# 2                    Instrument Currency
# 3                                 Ticker
# 4       Abbreviation of Reference Entity
# ..                                   ...
# 82                       Pair Is Current
# 83  Pref Obligation for this entity/tier
# 84             Special Features Comments
# 85                      Transaction Tier
# 86                 Transaction Type Name
#
# [87 rows x 4 columns]

# %%
dfdf = db.get_table(library="markit",table="redlookup")
dfdf
# Out:
#       redcode alt_redcode  distance   cusip     ticker  \
# 0      001AAV      6EA36E      -1.0  00191U    ASGNINC
# 1      001AAV      6EA36E       1.0  00191U    ASGNINC
# 2      001AEC        None       0.0  001957          T
# 3      002AA6        None       0.0  002824        ABT
# 4      002ABI      007D9P      -1.0  00283F   ABT-AMOI
# ...       ...         ...       ...     ...        ...
# 25846  YZAA9A        None       0.0  Y19182     DAHSIN
# 25847  YZAGF8        None       0.0  Y19780    DANGCAP
# 25848  YZSR4V        None       0.0  Y1R04R    CHINNAT
# 25849  YZSR6N        None       0.0  Y1R06H    CHINAPE
# 25850  Z05CAM        None       0.0  Z1482K  CDX-EMRes
#
#                             referenceentity
# 0                         ASGN Incorporated
# 1                         ASGN Incorporated
# 2                                AT&T Corp.
# 3                       Abbott Laboratories
# 4                Abbott Medical Optics Inc.
# ...                                     ...
# 25846   Dah Sing Financial Holdings Limited
# 25847                  Danga Capital Berhad
# 25848  China National Petroleum Corporation
# 25849       China Petrochemical Corporation
# 25850                   CDX.EM (Restricted)
#
# [25851 rows x 6 columns]

# %%
df.datadate
# Out:
# 0    1961-12-31
# 1    1962-12-31
# 2    1963-12-31
# 3    1964-12-31
# 4    1965-12-31
# 5    1966-12-31
# 6    1967-12-31
# 7    1968-12-31
# 8    1969-12-31
# 9    1970-12-31
# Name: datadate, dtype: object

# %%
db.list_tables(library="comp")[-20:]
# Out:
# ['seg_annfund',
#  'seg_customer',
#  'seg_geo',
#  'seg_naics',
#  'seg_product',
#  'seg_type',
#  'spidx_cst',
#  'spind',
#  'spind_dly',
#  'spind_mth',
#  'tmptable_pkg6153_tbl4023',
#  'wrds_g_exrate',
#  'wrds_idx_cst_current',
#  'wrds_ratios',
#  'wrds_seg_customer',
#  'wrds_seg_geo',
#  'wrds_seg_product',
#  'wrds_segmerged',
#  'xfl_column',
#  'xfl_table']

# %%
dealer_df
# Out:
#                                         Primary Dealer Start Date  \
# 9                 BANK OF NOVA SCOTIA, NEW YORK AGENCY 2011-10-04
# 11                               BARCLAYS CAPITAL INC. 1998-04-01
# 19                           BMO CAPITAL MARKETS CORP. 2011-10-04
# 21                        BNP PARIBAS SECURITIES CORP. 2000-09-15
# 28                             CANTOR FITZGERALD & CO. 2006-08-01
# 43                       CITIGROUP GLOBAL MARKETS INC. 2003-04-07
# 50                  CREDIT SUISSE SECURITIES (USA) LLC 2006-01-16
# 54                  DAIWA CAPITAL MARKETS AMERICA INC. 2010-04-01
# 61                       DEUTSCHE BANK SECURITIES INC. 2002-03-30
# 79                                GOLDMAN, SACHS & CO. 1974-12-04
# 85                          HSBC SECURITIES (USA) INC. 1999-06-01
# 91                          J.P. MORGAN SECURITIES LLC 2010-09-01
# 93                                       JEFFERIES LLC 2013-03-01
# 107  MERRILL LYNCH, PIERCE, FENNER & SMITH INCORPOR... 2010-11-01
# 110                         MIZUHO SECURITIES USA INC. 2002-04-01
# 112                           MORGAN STANLEY & CO. LLC 2011-05-31
# 120                NOMURA SECURITIES INTERNATIONAL,INC 2009-07-27
# 129                           RBC CAPITAL MARKETS, LLC 2010-11-01
# 130                                RBS SECURITIES INC. 2009-04-01
# 132                        SG AMERICAS SECURITIES, LLC 2011-02-02
# 151                            TD SECURITIES (USA) LLC 2014-02-11
# 157                                UBS SECURITIES LLC. 2003-06-09
#
#            End Date
# 9    Current Dealer
# 11   Current Dealer
# 19   Current Dealer
# 21   Current Dealer
# 28   Current Dealer
# 43   Current Dealer
# 50   Current Dealer
# 54   Current Dealer
# 61   Current Dealer
# 79   Current Dealer
# 85   Current Dealer
# 91   Current Dealer
# 93   Current Dealer
# 107  Current Dealer
# 110  Current Dealer
# 112  Current Dealer
# 120  Current Dealer
# 129  Current Dealer
# 130  Current Dealer
# 132  Current Dealer
# 151  Current Dealer
# 157  Current Dealer

# %%
query = f"""
    SELECT gvkey, datadate, indfmt, datafmt, consol, popsrc, conm
    FROM comp.fundq
    WHERE datadate = '2014-12-31'
"""
#     WHERE UPPER(a.conm) IN {dealer_names}
df = db.raw_sql(query)

# %%
df[df.conm.str.contains("DAIWA")]
# Out:
# Empty DataFrame
# Columns: [gvkey, datadate, indfmt, datafmt, consol, popsrc, conm]
# Index: []
